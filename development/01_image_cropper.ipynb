# %% [markdown]
# # Project 1: Image Cropper
#
# In this project we will be using NumPy to transform an image into an array, extract some basic information from it like its shape and size, and then crop it with a custom size. We will also be using PIL to read the image and Matplotlib to display it.
#
# There will be a default image to start with but this program shoud be able to work with any image.
#
# ### Project Tasks:
#
# - `1.1.` Take the image array `img_arr` and get its shape and size.
#
# - `1.2.` Define the dimensions of the crop, make sure that min is smaller than max and also that min is larger than 0 and max is smaller than the size of the image for every dimension. If not, print a message explaining the error.
#
# - `1.3.` Crop the image into a new array and display it.
#
# - `1.4.` Save the cropped image as a new file, declaring a variable to chose the new file name.

# %%
# !python -m pip install -r "../requirements.txt"
# Out:
# Requirement already satisfied: matplotlib in c:\users\user\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from -r ../requirements.txt (line 1)) (3.10.8)
# Requirement already satisfied: numpy in c:\users\user\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from -r ../requirements.txt (line 2)) (2.4.0)
# Requirement already satisfied: pandas in c:\users\user\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from -r ../requirements.txt (line 3)) (2.3.3)
# Requirement already satisfied: pillow in c:\users\user\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from -r ../requirements.txt (line 4)) (12.1.0)
# Requirement already satisfied: streamlit==1.52.0 in c:\users\user\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from -r ../requirements.txt (line 5)) (1.52.0)
# Requirement already satisfied: altair!=5.4.0,!=5.4.1,<7,>=4.0 in c:\users\user\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from streamlit==1.52.0->-r ../requirements.txt (line 5)) (6.0.0)
# Requirement already satisfied: blinker<2,>=1.5.0 in c:\users\user\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from streamlit==1.52.0->-r ../requirements.txt (line 5)) (1.9.0)
# Requirement already satisfied: cachetools<7,>=4.0 in c:\users\user\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from streamlit==1.52.0->-r ../requirements.txt (line 5)) (6.2.4)
# Requirement already satisfied: click<9,>=7.0 in c:\users\user\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from streamlit==1.52.0->-r ../requirements.txt (line 5)) (8.3.1)
# Requirement already satisfied: packaging>=20 in c:\users\user\appdata\roaming\python\python314\site-packages (from streamlit==1.52.0->-r ../requirements.txt (line 5)) (25.0)
# Requirement already satisfied: protobuf<7,>=3.20 in c:\users\user\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from streamlit==1.52.0->-r ../requirements.txt (line 5)) (6.33.2)
# Requirement already satisfied: pyarrow>=7.0 in c:\users\user\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from streamlit==1.52.0->-r ../requirements.txt (line 5)) (22.0.0)
# Requirement already satisfied: requests<3,>=2.27 in c:\users\user\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from streamlit==1.52.0->-r ../requirements.txt (line 5)) (2.32.5)
# Requirement already satisfied: tenacity<10,>=8.1.0 in c:\users\user\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from streamlit==1.52.0->-r ../requirements.txt (line 5)) (9.1.2)
# Requirement already satisfied: toml<2,>=0.10.1 in c:\users\user\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from streamlit==1.52.0->-r ../requirements.txt (line 5)) (0.10.2)
# Requirement already satisfied: typing-extensions<5,>=4.4.0 in c:\users\user\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from streamlit==1.52.0->-r ../requirements.txt (line 5)) (4.15.0)
# Requirement already satisfied: watchdog<7,>=2.1.5 in c:\users\user\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from streamlit==1.52.0->-r ../requirements.txt (line 5)) (6.0.0)
# Requirement already satisfied: gitpython!=3.1.19,<4,>=3.0.7 in c:\users\user\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from streamlit==1.52.0->-r ../requirements.txt (line 5)) (3.1.46)
# Requirement already satisfied: pydeck<1,>=0.8.0b4 in c:\users\user\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from streamlit==1.52.0->-r ../requirements.txt (line 5)) (0.9.1)
# Requirement already satisfied: tornado!=6.5.0,<7,>=6.0.3 in c:\users\user\appdata\roaming\python\python314\site-packages (from streamlit==1.52.0->-r ../requirements.txt (line 5)) (6.5.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\user\appdata\roaming\python\python314\site-packages (from pandas->-r ../requirements.txt (line 3)) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\user\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from pandas->-r ../requirements.txt (line 3)) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\user\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from pandas->-r ../requirements.txt (line 3)) (2025.3)
# Requirement already satisfied: jinja2 in c:\users\user\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit==1.52.0->-r ../requirements.txt (line 5)) (3.1.6)
# Requirement already satisfied: jsonschema>=3.0 in c:\users\user\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit==1.52.0->-r ../requirements.txt (line 5)) (4.25.1)
# Requirement already satisfied: narwhals>=1.27.1 in c:\users\user\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit==1.52.0->-r ../requirements.txt (line 5)) (2.14.0)
# Requirement already satisfied: colorama in c:\users\user\appdata\roaming\python\python314\site-packages (from click<9,>=7.0->streamlit==1.52.0->-r ../requirements.txt (line 5)) (0.4.6)
# Requirement already satisfied: gitdb<5,>=4.0.1 in c:\users\user\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from gitpython!=3.1.19,<4,>=3.0.7->streamlit==1.52.0->-r ../requirements.txt (line 5)) (4.0.12)
# Requirement already satisfied: smmap<6,>=3.0.1 in c:\users\user\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit==1.52.0->-r ../requirements.txt (line 5)) (5.0.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\user\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from requests<3,>=2.27->streamlit==1.52.0->-r ../requirements.txt (line 5)) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\user\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from requests<3,>=2.27->streamlit==1.52.0->-r ../requirements.txt (line 5)) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\user\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from requests<3,>=2.27->streamlit==1.52.0->-r ../requirements.txt (line 5)) (2.6.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\user\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from requests<3,>=2.27->streamlit==1.52.0->-r ../requirements.txt (line 5)) (2025.11.12)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\user\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from matplotlib->-r ../requirements.txt (line 1)) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\user\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from matplotlib->-r ../requirements.txt (line 1)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\user\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from matplotlib->-r ../requirements.txt (line 1)) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\user\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from matplotlib->-r ../requirements.txt (line 1)) (1.4.9)
# Requirement already satisfied: pyparsing>=3 in c:\users\user\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from matplotlib->-r ../requirements.txt (line 1)) (3.3.1)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\user\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from jinja2->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit==1.52.0->-r ../requirements.txt (line 5)) (3.0.3)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\user\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit==1.52.0->-r ../requirements.txt (line 5)) (25.4.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\user\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit==1.52.0->-r ../requirements.txt (line 5)) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\user\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit==1.52.0->-r ../requirements.txt (line 5)) (0.37.0)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\user\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit==1.52.0->-r ../requirements.txt (line 5)) (0.30.0)
# Requirement already satisfied: six>=1.5 in c:\users\user\appdata\roaming\python\python314\site-packages (from python-dateutil>=2.8.2->pandas->-r ../requirements.txt (line 3)) (1.17.0)
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# The library you have to use
import numpy as np

# Some extra libraries to deal with images and files
from PIL import Image
import matplotlib.pyplot as plt

# %%
img_path = "../data/starry_night.png"

with Image.open(img_path) as img:
    img_arr = np.array(img)

plt.imshow(img_arr)

# %%
# Ex 1.1: Get the height and width of the image in pixels
max_height = img_arr.shape[0]  
max_width = img_arr.shape[1]     

print(f"Height: {max_height} pixels")
print(f"Width: {max_width} pixels")
# Out:
# Height: 1089 pixels
# Width: 1377 pixels

# %%
# Ex 1.2: Define the dimensions of the crop, make sure that min is smaller than max and also that min is larger than 0 
# and max is smaller than the size of the image for every dimension. If not, print a message explaining the error.

# Example crop dimensions, modify them to test your code
crop_min_h = 600 
crop_max_h = 1000
crop_min_w = 550
crop_max_w = 1100

# Image dimensions
img_h, img_w = img_arr.shape[0], img_arr.shape[1]

# Height 
if crop_min_h <= 0:
    print("Error: crop_min_h must be greater than 0")

if crop_min_h >= crop_max_h:
    print("Error: crop_min_h must be smaller than crop_max_h")

if crop_max_h > img_h:
    print("Error: crop_max_h exceeds image height")

# Width 
if crop_min_w <= 0:
    print("Error: crop_min_w must be greater than 0")

if crop_min_w >= crop_max_w:
    print("Error: crop_min_w must be smaller than crop_max_w")

if crop_max_w > img_w:
    print("Error: crop_max_w exceeds image width")

# %%
# Ex 1.3: Generate the crop array into a new variable, use NumPy array slicing

crop_arr = img_arr[crop_min_h:crop_max_h, crop_min_w:crop_max_w]

# %%
# Display the cropped image

plt.imshow(crop_arr)

# %%
# Ex 1.4: Saving the cropped image into a new file, set the filename of the new image

crop_img = Image.fromarray(crop_arr)

file_name = "cropped_image"  

crop_img.save(f"../data/{file_name}.png")
